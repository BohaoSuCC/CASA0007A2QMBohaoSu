# %%
# import libraries
import os
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import scipy.stats
import statsmodels.api as sm

# from src import drop_column_using_vif_, show_vif_values

from statsmodels.stats.outliers_influence import variance_inflation_factor 
import imageio

# %%
# Open Measurements.csv in the data folder
Measurements = pd.read_csv(os.path.join('..','data', 'Measurements.csv'))

# %%
columns_to_apply = Measurements.columns.difference(['CSScode'])
Measurements[columns_to_apply] = Measurements[columns_to_apply].applymap(lambda x: 100*x if x<=1 else x)

# %%
Measurements.fillna(100.00)
# Out:
#       CSScode  Finance_Secure_2018  Finance_Secure_2019  Finance_Secure_2020  \
# 0   E09000001                 66.7                100.0                100.0
# 1   E09000002                 89.1                 86.3                 87.3
# 2   E09000003                 91.5                 91.7                 89.2
# 3   E09000004                 95.4                 94.5                 94.2
# 4   E09000005                 92.0                 88.4                 88.9
# 5   E09000006                 97.4                 96.8                 97.8
# 6   E09000007                 95.3                 94.7                 94.9
# 7   E09000008                 91.7                 91.4                 91.0
# 8   E09000009                 95.2                 96.4                 94.6
# 9   E09000010                 94.6                 93.9                 92.1
# 10  E09000011                 88.4                 89.5                 88.6
# ...

# %%
Measurements.to_csv(os.path.join("..","data","CleanedMeasurements.csv"))
